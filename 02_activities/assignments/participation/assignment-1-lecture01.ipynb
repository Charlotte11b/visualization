# %% [markdown]
# # Lecture 1 - January 15, 2026 #

# %% [markdown]
# ### Activity #1. Life Expectancy Graph ###
#
# - 3D view and shadow in the visuals are not useful
# - Redundant lables for the continents
# - Title is not clear. Is it average or max life expectancy?
# - It doesn't show how many samples were included to produce this graph.

# %% [markdown]
# ### Activity #2. Monstrous Graph ###
#
# - The visuals are eye-catching and memorable
# - Texts and data are too small to see clearly

# %% [markdown]
# ### Activity #3. Comparisons of line graphs ###
#
# - There is no title, labels, legends and source of data

# %% [markdown]
# ### Activity #4. Presidental Run Graph ###
#
# - The pie chart was created inaccurately
# - Background color and the pie colour are the same

# %% [markdown]
# ### Activity #5. Wind map Graph ###
#
# - B&W makes it hard to interpret
# - The differences between the levels of wind speed is hard to distinguish
# - Accuracy and source of data can be verified
# - Some of the states/cities are not shown. Why?

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613) # For reproducibility
x = np.arange(50) 
y = np.random.randint(0, 100, 50) # Random integers between 0 and 100

fig, ax = plt.subplots(figsize=(5, 3)) # Create a figure and axis
ax.scatter(x, y) # Scatter plot

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x, y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y, bins=10)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

font1 = {'family': 'sans-serif', 'color': 'blue', 'size': 20}
font2 = {'family': 'monospace', 'color': 'green', 'size': 14}

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y)
ax.set_title('Total growth over time', fontdict=font1)
ax.set_ylabel('Total growth', fontdict=font2)
ax.set_xlabel('Years since start', fontdict=font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y)
ax.set_ylabel('Total growth', fontdict=font2)
ax.set_xlabel('Years since start', fontdict=font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %%
fig, ax = plt.subplots(figsize=(5, 3))

ax.scatter(
    x,
    y,
    marker='*',      # NEW ADDITIONS
    color="indigo"   # NEW ADDITIONS
)

fig.show()
# Out:
# C:\Users\Charlotte\AppData\Local\Temp\ipykernel_14736\2453823979.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))

ax.plot(
    x,
    y,
    marker='*',
    color='indigo',
    linestyle='--',   # NEW ADDITIONS
    linewidth=2       # NEW ADDITIONS
)

fig.show()
# Out:
# C:\Users\Charlotte\AppData\Local\Temp\ipykernel_14736\3331421055.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))

# color being the new addition
ax.plot(
    x,
    y,
    marker='*',
    color='#7425b9',
    linestyle='--',
    linewidth=2
)

fig.show()
# Out:
# C:\Users\Charlotte\AppData\Local\Temp\ipykernel_14736\3958808740.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(
    x,
    y,
    marker='*',
    markersize=12,          # NEW ADDITIONS
    color='#7425b9',
    linestyle='--',
    linewidth=2,
    markeredgecolor='#fa9359',   # NEW ADDITIONS
    markerfacecolor='#000000'    # NEW ADDITIONS
)

fig.show()
# Out:
# C:\Users\Charlotte\AppData\Local\Temp\ipykernel_14736\2199320629.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(
    x,
    y,
    marker='*',
    markersize=12,          # NEW ADDITIONS
    color='#7425b9',
    linestyle='--',
    linewidth=2,
    markeredgecolor='#fa9359',   # NEW ADDITIONS
    markerfacecolor='#000000'    # NEW ADDITIONS
)
ax.grid(axis='y')
fig.show()
# Out:
# C:\Users\Charlotte\AppData\Local\Temp\ipykernel_14736\3172615006.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(
    x,
    y,
    marker='*',
    markersize=12,          # NEW ADDITIONS
    color='#7425b9',
    linestyle='--',
    linewidth=2,
    markeredgecolor='#fa9359',   # NEW ADDITIONS
    markerfacecolor='#000000'    # NEW ADDITIONS
)
ax.grid(axis='y', color="blue", linewidth=2, linestyle='-.')
fig.show()
# Out:
# C:\Users\Charlotte\AppData\Local\Temp\ipykernel_14736\2015946511.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Import necessary libraries
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Get the data (csv file is hosted on the web)
url = 'https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/volcano.csv'
data = pd.read_csv(url)

# Transform it to a long format
df = data.unstack().reset_index()
df.columns = ["X", "Y", "Z"]

# Transform the old column name in something numeric
df['X'] = pd.Categorical(df['X'])
df['X'] = df['X'].cat.codes

# Create the plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Plot the data
trisurf = ax.plot_trisurf(df['Y'], df['X'], df['Z'], cmap=plt.cm.viridis, linewidth=0.2)

# Set the angle of the camera
ax.view_init(30, 100)

# Add color bar which maps values to colors
fig.colorbar(trisurf, ax=ax, shrink=0.5, aspect=5)

# Show the plot
plt.show()
# Out:
# c:\Users\Charlotte\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\animation.py:872: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %% [markdown]
# ### Evaluation ###
# 1. Aesthetic: The plot is visually appealing, with a smooth 3D surface and a clear color gradient that makes changes in elevation easy to see.
# 2. Substantive: It effectively represents the volcano elevation data. The 3D surface and color bar together help show the overall shape, peaks, and valleys.
# 3. Perceptual: The visualization makes it easy to understand the general structure and relative height differences. However, exact values are harder to judge because 3D perspective can distort depth.
